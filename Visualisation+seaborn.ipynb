# %%
import pandas as pd
import numpy as np

# %%
np.random.seed(20)
df=pd.DataFrame(np.random.rand(10,4),index=pd.date_range('2021-07-18',periods=10),columns=['a','b','c','d'])
df
# Out:
#                    a         b         c         d
# 2021-07-18  0.588131  0.897714  0.891531  0.815837
# 2021-07-19  0.035890  0.691758  0.378681  0.518511
# 2021-07-20  0.657951  0.193850  0.272316  0.718606
# 2021-07-21  0.783004  0.850328  0.775245  0.036664
# 2021-07-22  0.116694  0.751281  0.239218  0.254806
# 2021-07-23  0.857626  0.949779  0.561687  0.178781
# 2021-07-24  0.770252  0.492381  0.631253  0.839498
# 2021-07-25  0.461039  0.497940  0.679411  0.650786
# 2021-07-26  0.268795  0.067325  0.771445  0.480984
# 2021-07-27  0.329206  0.510641  0.263629  0.310512

# %%
from plotly.offline import iplot
import plotly as py
import plotly.tools as tls
import cufflinks as cf
import seaborn as sns   
# %matplotlib inline

# %%
py.offline.init_notebook_mode(connected=True)            #configuring plotly-offline
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
# ...

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.iplot(kind='box')
# Out:
# <div>                            <div id="6f18ce94-50f7-4c86-be2f-3c9ea8443b7a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(x='a',y='b',z='c',kind='scatter3d')
# Out:
# <div>                            <div id="39d0305a-ff99-4a95-b07e-29a4b79eb934" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df['a1']=df.a + 10

# %%
df['b1']=df.a+30

# %%
df.iplot(x='a',y='a1',z='b1',kind='scatter3d')
# Out:
# <div>                            <div id="d391fd2e-175d-417d-b2d0-a16409a15bec" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df2= sns.load_dataset('titanic')
df2
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df2.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df2.iplot(x='age',y='fare',z='pclass',kind='scatter3d')
# Out:
# <div>                            <div id="7e9ff9be-c474-4987-9ed7-20ca674b3c95" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df2.iplot(x='age',y='fare',kind='scatter')
# Out:
# <div>                            <div id="aaef30c3-39b3-4fef-9345-4bb16cdfa71e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df2.iplot(x='age',y='fare',z='pclass',kind='bubble3d',size='fare')
# Out:
# <div>                            <div id="b29d365f-92bf-4c51-ac27-cf26842987ed" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
sns.relplot(x='age',y='fare',data=df2)

# %%
sns.relplot(x='age',y='fare',data=df2,hue='sex',style='alive')

# %%
sns.relplot(x='age',y='fare',data=df2,hue='sex',style='alive',size='pclass')

# %%
dfa=pd.DataFrame(np.random.randn(300,2),columns=['a','b'])
dfa
# Out:
#             a         b
# 0   -0.253897 -0.959602
# 1    0.914341 -0.679262
# 2   -1.045267  0.557916
# 3    1.141808 -0.813712
# 4    2.194295 -0.550061
# ..        ...       ...
# 295  1.635849 -1.037264
# 296 -1.226852  1.190075
# 297 -1.481225  0.492190
# 298 -1.052291 -0.587258
# 299  0.184959  0.719976
#
# [300 rows x 2 columns]

# %%
sns.relplot(x='a',y='b',kind='line',data=dfa,sort=True)

# %%
iris=sns.load_dataset('iris')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.scatterplot(x='sepal_length',y='sepal_width',data=iris)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
tip=sns.load_dataset('tips')
tip
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.catplot(x= 'day', y='tip',data=tip)           #cat plot can be uses to visualize info on categorical data

# %%
sns.catplot(x= 'sex', y='tip',data=tip)

# %%
sns.catplot(x='day',y='tip',kind='box',data=tip,hue='sex')

# %%
x=np.random.randn(10000)
x
# Out:
# array([-0.11063561, -0.39363265,  0.85037479, ..., -0.48319885,
#         1.36382854, -1.41907152])

# %%
sns.distplot(x)                 # when we increased data from 1000 to 10000 dist curve change to a more accurate dist curve, this is called central limit theorem
# Out:
# /home/o2bhai/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# <AxesSubplot:ylabel='Density'>

# %%
sns.jointplot(x=tip['total_bill'],y=tip['tip'])

# %%
y=np.random.rand(10000)
y
# Out:
# array([0.62709553, 0.06031816, 0.56124435, ..., 0.83454472, 0.23724944,
#        0.8055811 ])

# %%
sns.distplot(y)
# Out:
# /home/o2bhai/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# <AxesSubplot:ylabel='Density'>

# %%
sns.jointplot(x=tip['total_bill'],y=tip['tip'],kind='hex')

# %%
sns.pairplot(iris)

# %%
sns.lmplot(x='total_bill',y='tip',data=tip)     #lmplot is used to find the best fitted line, which we do in regression

# %%
# here we try regplot which is same as lmplot

sns.regplot(x='total_bill',y='tip',data=tip)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.lmplot(x='total_bill',y='tip',data=tip,col='day')
