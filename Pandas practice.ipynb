# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv",sep='\t')

# %%
df.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
df['total_cost']=df['quantity']*df['item_price']

# %%
df.head()             #not getting rt ans in totalcost as item price is in string type
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price total_cost
# 0                                                NaN     $2.39        NONE
# 1                                       [Clementine]     $3.39        NONE
# 2                                            [Apple]     $3.39        NONE
# 3                                                NaN     $2.39        NONE
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98        NONE

# %%
df['total_cost']='NONE'

# %%
for i in range(len(df)):
    df['item_price'][i]=float(df['item_price'][i][1:])
# Out:
# /tmp/ipykernel_8487/235372674.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['item_price'][i]=float(df['item_price'][i][1:])

# %%
float(df['item_price'][i][1:])
# Out:
# 8.75

# %%
df['item_price'][1]=df['total_cost'][1]                #sending one data to the list
# Out:
# /tmp/ipykernel_12022/3878006743.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['item_price'][1]=df['total_cost'][1]

# %%
df.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price total_cost
# 0                                                NaN       2.39       NONE
# 1                                       [Clementine]       3.39       NONE
# 2                                            [Apple]       3.39       NONE
# 3                                                NaN       2.39       NONE
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...      16.98       NONE

# %%
df['total_cost']=df['quantity']*df['item_price']

# %%
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price total_cost
# 0                                                   NaN       2.39       2.39
# ...

# %%
dl = pd.read_csv("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv",sep='\t')

# %%
dl.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %%
dl.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
dl.dtypes=='object'             #finding colums(lists) of object data type
# Out:
# order_id              False
# quantity              False
# item_name              True
# choice_description     True
# item_price             True
# dtype: bool

# %%
#will show only the columns with  dtypes object 
dl.dtypes[dl.dtypes=='object']                   #type - series
# Out:
# pandas.core.series.Series

# %%
dl[dl.dtypes[dl.dtypes=='object'].index]          #shows only dataframe with object dtype columns
# Out:
#                                   item_name  \
# 0              Chips and Fresh Tomato Salsa
# 1                                      Izze
# 2                          Nantucket Nectar
# 3     Chips and Tomatillo-Green Chili Salsa
# 4                              Chicken Bowl
# ...                                     ...
# 4617                          Steak Burrito
# 4618                          Steak Burrito
# 4619                     Chicken Salad Bowl
# 4620                     Chicken Salad Bowl
# 4621                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# 1                                          [Clementine]     $3.39
# 2                                               [Apple]     $3.39
# 3                                                   NaN     $2.39
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# ...

# %%
df['choice_description'].isnull()== True          #show df index where choice... is null
# Out:
# 0        True
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 4617    False
# 4618    False
# 4619    False
# 4620    False
# 4621    False
# Name: choice_description, Length: 4622, dtype: bool

# %%
df[df['choice_description'].isnull()== True]            #show df wher choice is null
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 6            3         1                          Side of Chips
# 10           5         1                    Chips and Guacamole
# 14           7         1                    Chips and Guacamole
# ...        ...       ...                                    ...
# 4600      1827         1                    Chips and Guacamole
# 4605      1828         1                    Chips and Guacamole
# 4613      1831         1                                  Chips
# 4614      1831         1                          Bottled Water
# 4616      1832         1                    Chips and Guacamole
#
#      choice_description item_price total_cost
# 0                   NaN       2.39       2.39
# 3                   NaN       2.39       2.39
# 6                   NaN       1.69       1.69
# ...

# %%
null_val=df[df['choice_description'].isnull()== True]
null_val.index
# Out:
# Int64Index([   0,    3,    6,   10,   14,   15,   20,   25,   30,   32,
#             ...
#             4582, 4584, 4588, 4596, 4598, 4600, 4605, 4613, 4614, 4616],
#            dtype='int64', length=1246)

# %%
len(null_val.index)
# Out:
# 1246

# %%
#max(df['item_price'])
max(df['total_cost'])
# Out:
# 663.75
